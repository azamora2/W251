# %%
# !python /tf/face-mask-detector4/image_detector.py
# Out:
# 2020-08-04 18:28:29.113486: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2020-08-04 18:28:29.113527: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ------------------LOADING FACE DETECTOR MODEL------------------------
# ----------------LOADING FACE MASK DETECTOR MODEL---------------------
# 2020-08-04 18:28:30.412233: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2020-08-04 18:28:30.412265: W tensorflow/stream_executor/cuda/cuda_driver.cc:312] failed call to cuInit: UNKNOWN ERROR (303)
# ...

# %%
# !pwd
# Out:
# /tf

# %%
import paho.mqtt.client as mqtt

# %%
pip install paho-mqtt
# Out:
# ...
#      |████████████████████████████████| 99 kB 5.7 MB/s  eta 0:00:01
# ...
#   Created wheel for paho-mqtt: filename=paho_mqtt-1.5.0-py3-none-any.whl size=74652 sha256=f6891a1d4be9904a5a3c8aab49742c57e53eef08fa9d8bdb180e0e333d75b9db
#   Stored in directory: /root/.cache/pip/wheels/b1/1e/85/172dc41f02d413a702530402d1fe56651bd662e72de5cec4af
# Successfully built paho-mqtt
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install opencv-python
# Out:
# ...
#      |████████████████████████████████| 43.7 MB 10.0 MB/s eta 0:00:01
# ...

# %%
# !echo Y|apt-get install python-opencv
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   adwaita-icon-theme at-spi2-core dconf-gsettings-backend dconf-service
#   fontconfig fontconfig-config fonts-dejavu-core gdal-data glib-networking
#   glib-networking-common glib-networking-services gsettings-desktop-schemas
#   gtk-update-icon-cache hicolor-icon-theme humanity-icon-theme i965-va-driver
#   ibverbs-providers libaacs0 libaec0 libarmadillo8 libarpack2
#   libatk-bridge2.0-0 libatk1.0-0 libatk1.0-data libatspi2.0-0 libavahi-client3
#   libavahi-common-data libavahi-common3 libavcodec57 libavformat57 libavutil55
#   libbdplus0 libblas3 libbluray2 libbsd0 libcairo-gobject2 libcairo2
#   libcharls1 libchromaprint1 libcolord2 libcroco3 libcrystalhd3 libcups2
#   libdap25 libdapclient6v5 libdatrie1 libdc1394-22 libdconf1 libdrm-amdgpu1
#   libdrm-common libdrm-intel1 libdrm-nouveau2 libdrm-radeon1 libdrm2 libedit2
# ...
